# %%
import pandas as pd
import numpy as np

# %%
banglore=pd.read_excel("/content/drive/My Drive/SAMPLE_DATA/medilabs/Hospital Data/banglore/linked_labs_distwise_banglore_all.xlsx")

# %%
banglore
# Out:
#      Unnamed: 0  index  ...   56   57
# 0             0   1375  ...  NaN  NaN
# 1             1   1376  ...  NaN  NaN
# 2             2   1377  ...  NaN  NaN
# 3             3   1378  ...  NaN  NaN
# 4             4   1379  ...  NaN  NaN
# ..          ...    ...  ...  ...  ...
# 381         381   1756  ...  NaN  NaN
# 382         382   1757  ...  NaN  NaN
# 383         383   1758  ...  NaN  NaN
# 384         384   1759  ...  NaN  NaN
# 385         385   1760  ...  NaN  NaN
#
# [386 rows x 59 columns]

# %%
from requests import get
search_url = "https://www.google.com/maps/search/"
var=f"diagnostic centre near Yellamma Dasappa Hospital in banglore"
var=var.replace(" ","+")
url=f"{search_url}{var}"
response = get(search_url)
print(url,response.text)
# Out:
# https://www.google.com/maps/search/diagnostic+centre+near+Yellamma+Dasappa+Hospital+in+banglore <!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Place" lang="en"> <head> <link href="/maps/preview/opensearch.xml?hl=en" title="Google Maps" rel="search" type="application/opensearchdescription+xml"> <title>  Google Maps  </title> <meta content=" Find local businesses, view maps and get driving directions in Google Maps. " name="Description">  <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"> <meta content="chrome=1" http-equiv="X-UA-Compatible"> <meta content="notranslate" name="google"> <meta content="origin" name="referrer">   <meta content="Google Maps" itemprop="name"> <meta content="Google Maps" property="og:title"> <meta content="https://maps.google.com/maps/api/staticmap?center=37.6%2C-95.665&amp;zoom=4&amp;size=256x256&amp;language=en&amp;sensor=false&amp;client=google-maps-frontend&amp;signature=SUtKsZvtCEDrvW
# ...
