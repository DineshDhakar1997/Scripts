# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_excel("/content/drive/My Drive/SAMPLE_DATA/medilabs/Hospital Data/hospital list of states with cities.xls")

# %%
data
# Out:
#                                 Hospital Name  ... Description
# 0                            Janatha Hospital  ...         NaN
# 1     Konaseema Ins of Medical Sciences(KIMS)  ...         NaN
# 2                         United Nursing Home  ...         NaN
# 3                            V.N.Nursing Home  ...         NaN
# 4           Chandra Super Speciality Hospital  ...         NaN
# ...                                       ...  ...         ...
# 5347        North Bengal Neuro Centre Pvt Ltd  ...         NaN
# 5348               Paramount Hospital Pvt.Ltd  ...         NaN
# 5349      Siliguri Greater Lions Eye Hospital  ...         NaN
# 5350             SUNRISE NURSING HOME PVT.LTD  ...         NaN
# 5351                      MAMATA NURSING HOME  ...         NaN
#
# [5352 rows x 10 columns]

# %%
banglore=data[data.City=="Bangalore"]
banglore=pd.DataFrame.reset_index(banglore)
len(banglore)



l=[]
for i in range(len(banglore["Pincode"])):
    l.append(int(banglore["Pincode"][i]))

banglore["pincodes"]=l

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:4 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ...

# %%
# open it, go to a website, and get results
driver = webdriver.Chrome(options=options)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-26-8db93b43ed4d> in <module>()
#       1 # open it, go to a website, and get results
# ----> 2 driver = webdriver.Chrome(options=options)
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
# ...

# %%
def list(hosp,city):

    search_url="https://www.google.com/maps/search/"
    #pincodes=pincodes.astype(str)


    var=f"diagnostic centre near {hosp} in {city}"
    var=var.replace(" ","+")
    url=f"{search_url}{var}"
    driver.get(f"{url}")
    print(driver.page_source)
    res=driver.find_elements_by_class_name("section-result-title")
    add=driver.find_elements_by_class_name("section-result-location")



    banglore.at[i,12]= len(res)
    banglore.at[i,13]= url
    print(f"hospital {i+1}",f"{len(res)} results",url)

    for j in range(0,len(res)):
        banglore.at[i,14+2*j]=res[j].text
        banglore.at[i,14+2*j+1]=add[j].text

# %%
for i in range(0,2):
    list(banglore.loc[i,"Hospital Name"],banglore.loc[i,"City"])

# %%
banglore.head(2).T
# Out:
#                                                                0                                                  1
# index                                                       1375                                               1376
# Hospital Name                             Aashirvad Nursing Home                                 AAYUGS HEALTH CARE
# Addr1           70/3 6th Bandireddy Circle Srirampuram Bangalore  # 477 1st main, B Block Aecs Layout, Kundanahalli
# Addr2                                                        NaN                                                NaN
# Addr3                                                        NaN                                                NaN
# City                                                   Bangalore                                          Bangalore
# Pincode                                                   560021                                             560037
# ...
